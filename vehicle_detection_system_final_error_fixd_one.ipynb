# %% [markdown]
# <a href="https://colab.research.google.com/github/sh13y/100-days-of-javascript/blob/master/vehicle_detection_system_final_error_fixd_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# ICT 3212 - Vehicle Detection System using CNN
# FINAL CORRECTED VERSION – Overfitting Fixed
# Rajarata University of Sri Lanka | Department of Computing
# ============================================================

# ============================================================
# CELL 1: Mount Google Drive & Extract Dataset
# ============================================================

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os, shutil, random

zip_path    = '/content/drive/MyDrive/vehicle_dataset.zip'
extract_dir = '/content/vehicle_dataset'

if not os.path.exists(extract_dir):
    print("Extracting dataset …")
    with zipfile.ZipFile(zip_path, 'r') as zf:
        zf.extractall(extract_dir)
    print("Done!")
else:
    print("Dataset folder already exists – skipping extraction.")

TRAIN_DIR = '/content/vehicle_dataset/vehicle_dataset/train'
TEST_DIR  = '/content/vehicle_dataset/vehicle_dataset/test'

# ============================================================
# CELL 2: Fix Folder Names
# ============================================================

rename_train = {'Car': 'car', 'trucks': 'truck', 'Bike': 'motorcycle'}
for old, new in rename_train.items():
    old_path = os.path.join(TRAIN_DIR, old)
    new_path = os.path.join(TRAIN_DIR, new)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"  ✅ Renamed: train/{old} → train/{new}")

rename_test = {'bike': 'motorcycle'}
for old, new in rename_test.items():
    old_path = os.path.join(TEST_DIR, old)
    new_path = os.path.join(TEST_DIR, new)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"  ✅ Renamed: test/{old} → test/{new}")

print("Train folders:", os.listdir(TRAIN_DIR))
print("Test folders :", os.listdir(TEST_DIR))

# ============================================================
# CELL 3: Populate Empty Test Folders
# ============================================================

CLASS_NAMES = ['car', 'bus', 'truck', 'motorcycle']
random.seed(42)

for cls in CLASS_NAMES:
    train_cls = os.path.join(TRAIN_DIR, cls)
    test_cls  = os.path.join(TEST_DIR,  cls)
    os.makedirs(test_cls, exist_ok=True)

    existing = [f for f in os.listdir(test_cls)
                if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if len(existing) > 0:
        print(f"  ✅ {cls:12s} → already has {len(existing)} test images")
        continue

    all_images = [f for f in os.listdir(train_cls)
                  if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    random.shuffle(all_images)
    test_count = max(1, int(len(all_images) * 0.2))

    for img_name in all_images[:test_count]:
        shutil.copy2(os.path.join(train_cls, img_name),
                     os.path.join(test_cls,  img_name))
    print(f"  ✅ {cls:12s} → {test_count} images copied to test/")

print("\nFinal Dataset Structure:")
print("=" * 45)
for split, path_dir in [('train', TRAIN_DIR), ('test', TEST_DIR)]:
    print(f"\n  {split.upper()}/")
    for cls in CLASS_NAMES:
        path  = os.path.join(path_dir, cls)
        count = len([f for f in os.listdir(path)
                     if f.lower().endswith(('.jpg','.jpeg','.png'))]) \
                if os.path.exists(path) else 0
        print(f"    {'✅' if count > 0 else '❌'} {cls:12s}: {count} images")
print("=" * 45)

# ============================================================
# CELL 4: Import Libraries
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix

print("All libraries imported successfully!")

# ============================================================
# CELL 5: Configuration
# ✅ FIX 1: Batch size changed to 64
# ============================================================

DISPLAY_NAMES = ['Car', 'Bus', 'Truck', 'Motorcycle']
NUM_CLASSES   = 4
IMG_HEIGHT    = 128
IMG_WIDTH     = 128
EPOCHS        = 30
BATCH_SIZE    = 64        # ✅ changed from 32 → 64

print(f"  Image size  : {IMG_HEIGHT} x {IMG_WIDTH}")
print(f"  Max epochs  : {EPOCHS}")
print(f"  Batch size  : {BATCH_SIZE}  ✅ (changed from 32)")
print(f"  Classes     : {CLASS_NAMES}")

# ============================================================
# CELL 6: Data Generators
# ✅ FIX 2: Reduced augmentation strength to fix val > train gap
# ============================================================

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,              # ✅ reduced from 20
    width_shift_range=0.15,         # ✅ reduced from 0.2
    height_shift_range=0.15,        # ✅ reduced from 0.2
    shear_range=0.10,               # ✅ reduced from 0.15
    zoom_range=0.15,                # ✅ reduced from 0.2
    horizontal_flip=True,
    brightness_range=[0.85, 1.15],  # ✅ narrowed from [0.8, 1.2]
    channel_shift_range=15.0,       # ✅ reduced from 20.0
    fill_mode='nearest',
    validation_split=0.20           # ✅ increased from 0.2 (same – keep stable)
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Training data
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    subset='training',
    shuffle=True,
    seed=42
)

# Validation data
val_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    subset='validation',
    shuffle=False,
    seed=42
)

# Test data
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)

print(f"\nTraining   batches : {len(train_generator)}")
print(f"Validation batches : {len(val_generator)}")
print(f"Test       batches : {len(test_generator)}")

# ============================================================
# CELL 7: Visualize Sample Images
# ============================================================

sample_X, sample_y = next(train_generator)

plt.figure(figsize=(14, 7))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(sample_X[i])
    plt.title(DISPLAY_NAMES[np.argmax(sample_y[i])], fontsize=9)
    plt.axis('off')
plt.suptitle('Sample Augmented Training Images (128x128)', fontsize=14)
plt.tight_layout()
plt.show()

# ============================================================
# CELL 8: Class Distribution
# ============================================================

train_counts, test_counts = [], []
for cls in CLASS_NAMES:
    tr = os.path.join(TRAIN_DIR, cls)
    te = os.path.join(TEST_DIR,  cls)
    train_counts.append(len([f for f in os.listdir(tr)
                              if f.lower().endswith(('.jpg','.jpeg','.png'))]))
    test_counts.append( len([f for f in os.listdir(te)
                              if f.lower().endswith(('.jpg','.jpeg','.png'))]))

x, width = np.arange(NUM_CLASSES), 0.35
fig, ax  = plt.subplots(figsize=(10, 5))
b1 = ax.bar(x - width/2, train_counts, width, label='Train', color='#2196F3')
b2 = ax.bar(x + width/2, test_counts,  width, label='Test',  color='#FF5722')
ax.set_xlabel('Vehicle Class')
ax.set_ylabel('Number of Images')
ax.set_title('Class Distribution – Train vs Test')
ax.set_xticks(x)
ax.set_xticklabels(DISPLAY_NAMES)
ax.legend()
ax.bar_label(b1, padding=3)
ax.bar_label(b2, padding=3)
plt.tight_layout()
plt.show()

print("\nImage counts:")
for cls, tr, te in zip(DISPLAY_NAMES, train_counts, test_counts):
    print(f"  {cls:12s} – Train: {tr:4d}  |  Test: {te:4d}")

# ============================================================
# CELL 9: Build CNN Model
# ✅ FIX 3: Reduced dropout in all blocks to fix val > train gap
# ============================================================

model = keras.Sequential([

    # ── Conv Block 1 – 32 filters ─────────────────────────
    layers.Conv2D(32, (3,3), activation='relu',
                  padding='same', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    BatchNormalization(),
    layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),        # 128 → 64
    Dropout(0.20),                     # ✅ reduced from 0.25

    # ── Conv Block 2 – 64 filters ─────────────────────────
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),        # 64 → 32
    Dropout(0.20),                     # ✅ reduced from 0.25

    # ── Conv Block 3 – 128 filters ────────────────────────
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),        # 32 → 16
    Dropout(0.25),                     # ✅ slightly reduced from 0.25 (same)

    # ── Conv Block 4 – 256 filters ────────────────────────
    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),        # 16 → 8
    Dropout(0.25),                     # ✅ kept same

    # ── Classifier Head ───────────────────────────────────
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.40),                     # ✅ reduced from 0.50
    layers.Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.30),                     # ✅ reduced from 0.40
    layers.Dense(128, activation='relu'),
    Dropout(0.20),                     # ✅ reduced from 0.30

    # Output – 4 vehicle classes
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.summary()

# ============================================================
# CELL 10: Compile the Model
# ✅ FIX 4: Slightly higher learning rate (0.0005 → 0.0008)
# ============================================================

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0008),  # ✅ increased from 0.0005
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Model compiled!")
print(f"  Optimizer    : Adam (lr=0.0008)  ✅ increased from 0.0005")
print(f"  Loss         : categorical_crossentropy")
print(f"  Metrics      : accuracy")

# ============================================================
# CELL 11: Callbacks
# ✅ FIX 5: Adjusted patience values
# ============================================================

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=7,                  # ✅ reduced from 8
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,                  # ✅ reduced from 4
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        '/content/drive/MyDrive/best_vehicle_model_fixed.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

print("Callbacks ready!")
print("  ✔ EarlyStopping     patience=7")
print("  ✔ ReduceLROnPlateau patience=3, factor=0.5")
print("  ✔ ModelCheckpoint   → saved to Google Drive")

# ============================================================
# CELL 12: Train the Model
# ============================================================

print("\n" + "="*50)
print("  STARTING TRAINING")
print(f"  Image size : {IMG_HEIGHT}x{IMG_WIDTH}")
print(f"  Max epochs : {EPOCHS}")
print(f"  Batch size : {BATCH_SIZE}")
print("="*50 + "\n")

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=callbacks,
    verbose=1
)

print("\nTraining completed!")

# ============================================================
# CELL 13: Visualize Training History + Overfitting Diagnostic
# ============================================================

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

epochs_ran = range(1, len(history.history['accuracy']) + 1)

# Accuracy plot
axes[0].plot(epochs_ran, history.history['accuracy'],
             label='Training',   linewidth=2, color='#2196F3')
axes[0].plot(epochs_ran, history.history['val_accuracy'],
             label='Validation', linewidth=2, color='#FF5722')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Model Accuracy Over Time')
axes[0].legend()
axes[0].grid(True, alpha=0.3)
axes[0].set_ylim([0, 1])

# Loss plot
axes[1].plot(epochs_ran, history.history['loss'],
             label='Training',   linewidth=2, color='#2196F3')
axes[1].plot(epochs_ran, history.history['val_loss'],
             label='Validation', linewidth=2, color='#FF5722')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].set_title('Model Loss Over Time')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

best_val_acc    = max(history.history['val_accuracy'])
final_train_acc = history.history['accuracy'][-1]
final_val_acc   = history.history['val_accuracy'][-1]
gap             = abs(final_val_acc - final_train_acc)

print(f"\nBest Validation Accuracy : {best_val_acc * 100:.2f}%")
print(f"Total Epochs Trained     : {len(history.history['accuracy'])}")

# ✅ Overfitting Diagnostic
print('\n' + '=' * 55)
print('       OVERFITTING DIAGNOSTIC REPORT')
print('=' * 55)
print(f'  Training Accuracy   : {final_train_acc*100:.2f}%')
print(f'  Validation Accuracy : {final_val_acc*100:.2f}%')
print(f'  Gap (|Val - Train|) : {gap*100:.2f}%')
print('─' * 55)
if gap < 0.05:
    print('  ✅ GOOD FIT   – Gap under 5%  – model generalizes well')
elif gap < 0.10:
    print('  ⚠️  MILD GAP  – Gap 5–10%    – acceptable result')
else:
    print('  ❌ HIGH GAP   – Gap over 10%  – overfitting present')
    print('     Suggestion: reduce dropout further or augmentation')
print('=' * 55)

# ============================================================
# CELL 14: Evaluate on Test Set
# ============================================================

# Final evaluation
test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
print(f'\nTest Accuracy : {test_accuracy * 100:.2f}%')
print(f'Test Loss     : {test_loss:.4f}')

# Predictions
y_prob = model.predict(test_generator, verbose=0)
y_pred = np.argmax(y_prob, axis=1)
y_true = test_generator.classes

# ============================================================
# CELL 15: Classification Report
# ============================================================

print("\nClassification Report:")
print("=" * 60)
print(classification_report(y_true, y_pred,
                             target_names=DISPLAY_NAMES, digits=3))

# ============================================================
# CELL 16: Confusion Matrix
# ============================================================

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=DISPLAY_NAMES, yticklabels=DISPLAY_NAMES,
            linewidths=0.5)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label',      fontsize=12)
plt.title('Confusion Matrix – Vehicle Detection', fontsize=14)
plt.tight_layout()
plt.show()

print("\nPer-Class Accuracy:")
print("-" * 45)
for i, cls in enumerate(DISPLAY_NAMES):
    correct = cm[i, i]
    total   = cm[i].sum()
    acc     = correct / total * 100
    bar     = '█' * int(acc / 5)
    print(f"  {cls:12s}: {correct}/{total}  {bar} {acc:.1f}%")

# ============================================================
# CELL 17: Visualize Predictions
# ============================================================

test_batch_X, test_batch_y = next(
    test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=16,
        class_mode='categorical',
        classes=CLASS_NAMES,
        shuffle=True,
        seed=99
    )
)

pred_probs  = model.predict(test_batch_X, verbose=0)
pred_labels = np.argmax(pred_probs, axis=1)
true_labels = np.argmax(test_batch_y, axis=1)

plt.figure(figsize=(16, 9))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(test_batch_X[i])
    t = DISPLAY_NAMES[true_labels[i]]
    p = DISPLAY_NAMES[pred_labels[i]]
    c = pred_probs[i][pred_labels[i]] * 100
    plt.title(f"T: {t}\nP: {p} ({c:.0f}%)",
              fontsize=8, color='green' if t == p else 'red')
    plt.axis('off')

plt.suptitle('Predictions (Green=Correct | Red=Wrong)', fontsize=13)
plt.tight_layout()
plt.show()

# ============================================================
# CELL 18: Predict Single Image
# ============================================================

from tensorflow.keras.preprocessing import image as keras_image

def predict_single_vehicle(img_path):
    img    = keras_image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    arr    = keras_image.img_to_array(img) / 255.0
    inp    = np.expand_dims(arr, axis=0)
    probs  = model.predict(inp, verbose=0)[0]
    pred   = np.argmax(probs)
    colors = ['#4CAF50' if i == pred else '#90CAF9' for i in range(NUM_CLASSES)]

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Input Image', fontsize=13)
    plt.axis('off')

    plt.subplot(1, 2, 2)
    bars = plt.barh(DISPLAY_NAMES, probs * 100, color=colors)
    plt.xlabel('Confidence (%)', fontsize=12)
    plt.title(f"Predicted: {DISPLAY_NAMES[pred]} ({probs[pred]*100:.1f}%)", fontsize=13)
    plt.xlim(0, 100)
    plt.grid(axis='x', alpha=0.3)
    for bar, p in zip(bars, probs):
        plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2,
                 f'{p*100:.1f}%', va='center', fontsize=10)
    plt.tight_layout()
    plt.show()

    print("\nConfidence Scores:")
    for name, p in zip(DISPLAY_NAMES, probs):
        print(f"  {name:12s} {'█' * int(p*40)} {p*100:.2f}%")

# Example usage:
# predict_single_vehicle('/content/vehicle_dataset/vehicle_dataset/test/car/Car (1).jpeg')

# ============================================================
# CELL 19: Save Model
# ============================================================

save_path = '/content/drive/MyDrive/vehicle_detection_final_fixed.h5'
model.save(save_path)
print(f"Model saved: {save_path}")

# ============================================================
# CELL 20: Final Summary
# ============================================================

print("\n" + "="*60)
print("    VEHICLE DETECTION CNN – FINAL CORRECTED RESULTS")
print("="*60)
print(f"  Image Size       : {IMG_HEIGHT} x {IMG_WIDTH}")
print(f"  Batch Size       : {BATCH_SIZE}")
print(f"  Epochs Trained   : {len(history.history['accuracy'])} / {EPOCHS}")
print(f"  Best Val Accuracy: {best_val_acc * 100:.2f}%")
print(f"  Test Accuracy    : {test_accuracy * 100:.2f}%")
print(f"  Test Loss        : {test_loss:.4f}")
print(f"  Train/Val Gap    : {gap * 100:.2f}%")
print("─"*60)
print("  OVERFITTING FIXES APPLIED:")
print("  ✅ Batch size        : 32     → 64")
print("  ✅ Dropout blocks 1&2: 0.25   → 0.20")
print("  ✅ Dropout head      : 0.50   → 0.40")
print("  ✅ Learning rate     : 0.0005 → 0.0008")
print("  ✅ Augmentation      : reduced all ranges")
print("  ✅ EarlyStopping     : patience 8 → 7")
print("  ✅ ReduceLROnPlateau : patience 4 → 3")
print("  ✅ Diagnostic report : added after training")
print("="*60)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset folder already exists – skipping extraction.
# Train folders: ['truck', 'bus', 'car', 'motorcycle']
# Test folders : ['truck', 'bus', 'car', 'motorcycle']
#   ✅ car          → already has 200 test images
#   ✅ bus          → already has 200 test images
#   ✅ truck        → already has 200 test images
#   ✅ motorcycle   → already has 200 test images
#
# Final Dataset Structure:
# =============================================
#
#   TRAIN/
#     ✅ car         : 1000 images
#     ✅ bus         : 1000 images
#     ✅ truck       : 1000 images
#     ✅ motorcycle  : 1000 images
#
#   TEST/
#     ✅ car         : 200 images
#     ✅ bus         : 200 images
#     ✅ truck       : 200 images
#     ✅ motorcycle  : 200 images
# =============================================
# All libraries imported successfully!
#   Image size  : 128 x 128
#   Max epochs  : 30
#   Batch size  : 64  ✅ (changed from 32)
#   Classes     : ['car', 'bus', 'truck', 'motorcycle']
# Found 3200 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
#
# Training   batches : 50
# Validation batches : 13
# Test       batches : 13
# Image counts:
#   Car          – Train: 1000  |  Test:  200
#   Bus          – Train: 1000  |  Test:  200
#   Truck        – Train: 1000  |  Test:  200
#   Motorcycle   – Train: 1000  |  Test:  200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_32 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_33 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_34 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,733,028 (37.13 MB)
#  Trainable params: 9,729,572 (37.12 MB)
#  Non-trainable params: 3,456 (13.50 KB)
# Model compiled!
#   Optimizer    : Adam (lr=0.0008)  ✅ increased from 0.0005
#   Loss         : categorical_crossentropy
#   Metrics      : accuracy
# Callbacks ready!
#   ✔ EarlyStopping     patience=7
#   ✔ ReduceLROnPlateau patience=3, factor=0.5
#   ✔ ModelCheckpoint   → saved to Google Drive
#
# ==================================================
#   STARTING TRAINING
#   Image size : 128x128
#   Max epochs : 30
#   Batch size : 64
# ==================================================
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 24/50 ━━━━━━━━━━━━━━━━━━━━ 15s 595ms/step - accuracy: 0.3413 - loss: 1.7073
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.3986 - loss: 1.5549
# Epoch 1: val_accuracy improved from -inf to 0.25000, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 888ms/step - accuracy: 0.4003 - loss: 1.5503 - val_accuracy: 0.2500 - val_loss: 1.8316 - learning_rate: 8.0000e-04
# Epoch 2/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 699ms/step - accuracy: 0.5971 - loss: 1.0260
# Epoch 2: val_accuracy improved from 0.25000 to 0.25250, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 967ms/step - accuracy: 0.5973 - loss: 1.0255 - val_accuracy: 0.2525 - val_loss: 1.6845 - learning_rate: 8.0000e-04
# Epoch 3/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.6586 - loss: 0.8823
# Epoch 3: val_accuracy did not improve from 0.25250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 834ms/step - accuracy: 0.6588 - loss: 0.8817 - val_accuracy: 0.2512 - val_loss: 1.6454 - learning_rate: 8.0000e-04
# Epoch 4/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 0.7399 - loss: 0.6746
# Epoch 4: val_accuracy did not improve from 0.25250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 40s 807ms/step - accuracy: 0.7401 - loss: 0.6743 - val_accuracy: 0.2500 - val_loss: 3.9190 - learning_rate: 8.0000e-04
# Epoch 5/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.7909 - loss: 0.5686
# Epoch 5: val_accuracy improved from 0.25250 to 0.29250, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 842ms/step - accuracy: 0.7909 - loss: 0.5684 - val_accuracy: 0.2925 - val_loss: 2.8630 - learning_rate: 8.0000e-04
# Epoch 6/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.8194 - loss: 0.5008
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
#
# Epoch 6: val_accuracy did not improve from 0.29250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 818ms/step - accuracy: 0.8192 - loss: 0.5009 - val_accuracy: 0.2537 - val_loss: 1.9449 - learning_rate: 8.0000e-04
# Epoch 7/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.8027 - loss: 0.5193
# Epoch 7: val_accuracy improved from 0.29250 to 0.30875, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 831ms/step - accuracy: 0.8030 - loss: 0.5187 - val_accuracy: 0.3088 - val_loss: 1.5874 - learning_rate: 4.0000e-04
# Epoch 8/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.8421 - loss: 0.4236
# Epoch 8: val_accuracy did not improve from 0.30875
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 839ms/step - accuracy: 0.8420 - loss: 0.4239 - val_accuracy: 0.2875 - val_loss: 1.9367 - learning_rate: 4.0000e-04
# Epoch 9/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.8352 - loss: 0.4169
# Epoch 9: val_accuracy improved from 0.30875 to 0.35625, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 44s 877ms/step - accuracy: 0.8354 - loss: 0.4169 - val_accuracy: 0.3562 - val_loss: 2.1904 - learning_rate: 4.0000e-04
# Epoch 10/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 643ms/step - accuracy: 0.8631 - loss: 0.3540
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
#
# Epoch 10: val_accuracy did not improve from 0.35625
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 827ms/step - accuracy: 0.8630 - loss: 0.3543 - val_accuracy: 0.3413 - val_loss: 1.8195 - learning_rate: 4.0000e-04
# Epoch 11/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 0.8448 - loss: 0.3907
# Epoch 11: val_accuracy improved from 0.35625 to 0.53875, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 832ms/step - accuracy: 0.8451 - loss: 0.3899 - val_accuracy: 0.5387 - val_loss: 1.1197 - learning_rate: 2.0000e-04
# Epoch 12/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.8689 - loss: 0.3425
# Epoch 12: val_accuracy improved from 0.53875 to 0.65750, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 44s 885ms/step - accuracy: 0.8689 - loss: 0.3426 - val_accuracy: 0.6575 - val_loss: 1.0564 - learning_rate: 2.0000e-04
# Epoch 13/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - accuracy: 0.8643 - loss: 0.3364
# Epoch 13: val_accuracy improved from 0.65750 to 0.75125, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 45s 887ms/step - accuracy: 0.8644 - loss: 0.3361 - val_accuracy: 0.7513 - val_loss: 0.7879 - learning_rate: 2.0000e-04
# Epoch 14/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.8850 - loss: 0.3024
# Epoch 14: val_accuracy did not improve from 0.75125
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 839ms/step - accuracy: 0.8848 - loss: 0.3027 - val_accuracy: 0.7063 - val_loss: 1.0378 - learning_rate: 2.0000e-04
# Epoch 15/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.8685 - loss: 0.3287
# Epoch 15: val_accuracy did not improve from 0.75125
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 40s 792ms/step - accuracy: 0.8687 - loss: 0.3284 - val_accuracy: 0.6963 - val_loss: 0.6998 - learning_rate: 2.0000e-04
# Epoch 16/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.8888 - loss: 0.3088
# Epoch 16: val_accuracy improved from 0.75125 to 0.79125, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 814ms/step - accuracy: 0.8887 - loss: 0.3087 - val_accuracy: 0.7912 - val_loss: 0.5708 - learning_rate: 2.0000e-04
# Epoch 17/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - accuracy: 0.8759 - loss: 0.3235
# Epoch 17: val_accuracy did not improve from 0.79125
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 40s 805ms/step - accuracy: 0.8759 - loss: 0.3234 - val_accuracy: 0.7887 - val_loss: 0.5864 - learning_rate: 2.0000e-04
# Epoch 18/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.8775 - loss: 0.3070
# Epoch 18: val_accuracy improved from 0.79125 to 0.82000, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 840ms/step - accuracy: 0.8778 - loss: 0.3067 - val_accuracy: 0.8200 - val_loss: 0.4526 - learning_rate: 2.0000e-04
# Epoch 19/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 675ms/step - accuracy: 0.8764 - loss: 0.2916
# Epoch 19: val_accuracy did not improve from 0.82000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 822ms/step - accuracy: 0.8765 - loss: 0.2918 - val_accuracy: 0.8062 - val_loss: 0.4748 - learning_rate: 2.0000e-04
# Epoch 20/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.8795 - loss: 0.2909
# Epoch 20: val_accuracy improved from 0.82000 to 0.82375, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 43s 872ms/step - accuracy: 0.8795 - loss: 0.2911 - val_accuracy: 0.8238 - val_loss: 0.4756 - learning_rate: 2.0000e-04
# Epoch 21/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.8845 - loss: 0.2956
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#
# Epoch 21: val_accuracy did not improve from 0.82375
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 819ms/step - accuracy: 0.8845 - loss: 0.2957 - val_accuracy: 0.7812 - val_loss: 0.5318 - learning_rate: 2.0000e-04
# Epoch 22/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.8845 - loss: 0.2837
# Epoch 22: val_accuracy did not improve from 0.82375
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 39s 785ms/step - accuracy: 0.8846 - loss: 0.2837 - val_accuracy: 0.8050 - val_loss: 0.5159 - learning_rate: 1.0000e-04
# Epoch 23/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.8916 - loss: 0.2800
# Epoch 23: val_accuracy improved from 0.82375 to 0.82875, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 839ms/step - accuracy: 0.8918 - loss: 0.2796 - val_accuracy: 0.8288 - val_loss: 0.3916 - learning_rate: 1.0000e-04
# Epoch 24/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 645ms/step - accuracy: 0.9132 - loss: 0.2316
# Epoch 24: val_accuracy improved from 0.82875 to 0.83000, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 44s 881ms/step - accuracy: 0.9130 - loss: 0.2320 - val_accuracy: 0.8300 - val_loss: 0.4223 - learning_rate: 1.0000e-04
# Epoch 25/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9097 - loss: 0.2356
# Epoch 25: val_accuracy did not improve from 0.83000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 831ms/step - accuracy: 0.9096 - loss: 0.2358 - val_accuracy: 0.8025 - val_loss: 0.5569 - learning_rate: 1.0000e-04
# Epoch 26/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - accuracy: 0.9025 - loss: 0.2455
# Epoch 26: val_accuracy improved from 0.83000 to 0.84375, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 43s 864ms/step - accuracy: 0.9025 - loss: 0.2456 - val_accuracy: 0.8438 - val_loss: 0.3875 - learning_rate: 1.0000e-04
# Epoch 27/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.8978 - loss: 0.2464
# Epoch 27: val_accuracy improved from 0.84375 to 0.85250, saving model to /content/drive/MyDrive/best_vehicle_model_fixed.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 45s 906ms/step - accuracy: 0.8978 - loss: 0.2465 - val_accuracy: 0.8525 - val_loss: 0.3870 - learning_rate: 1.0000e-04
# Epoch 28/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.9066 - loss: 0.2257
# Epoch 28: val_accuracy did not improve from 0.85250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 42s 840ms/step - accuracy: 0.9067 - loss: 0.2257 - val_accuracy: 0.8000 - val_loss: 0.6249 - learning_rate: 1.0000e-04
# Epoch 29/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 616ms/step - accuracy: 0.9038 - loss: 0.2660
# Epoch 29: val_accuracy did not improve from 0.85250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 40s 796ms/step - accuracy: 0.9040 - loss: 0.2654 - val_accuracy: 0.8450 - val_loss: 0.3995 - learning_rate: 1.0000e-04
# Epoch 30/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.9033 - loss: 0.2420
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 30: val_accuracy did not improve from 0.85250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 38s 771ms/step - accuracy: 0.9035 - loss: 0.2419 - val_accuracy: 0.8325 - val_loss: 0.4449 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 27.
#
# Training completed!
# Best Validation Accuracy : 85.25%
# Total Epochs Trained     : 30
#
# =======================================================
#        OVERFITTING DIAGNOSTIC REPORT
# =======================================================
#   Training Accuracy   : 91.00%
#   Validation Accuracy : 83.25%
#   Gap (|Val - Train|) : 7.75%
# ───────────────────────────────────────────────────────
#   ⚠️  MILD GAP  – Gap 5–10%    – acceptable result
# =======================================================
#
# Test Accuracy : 85.00%
# Test Loss     : 0.4348
#
# Classification Report:
# ============================================================
#               precision    recall  f1-score   support
#
#          Car      0.977     0.865     0.918       200
#          Bus      0.670     0.995     0.801       200
#        Truck      0.895     0.725     0.801       200
#   Motorcycle      0.994     0.815     0.896       200
#
#     accuracy                          0.850       800
#    macro avg      0.884     0.850     0.854       800
# weighted avg      0.884     0.850     0.854       800
# Per-Class Accuracy:
# ---------------------------------------------
#   Car         : 173/200  █████████████████ 86.5%
#   Bus         : 199/200  ███████████████████ 99.5%
#   Truck       : 145/200  ██████████████ 72.5%
#   Motorcycle  : 163/200  ████████████████ 81.5%
# Found 800 images belonging to 4 classes.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved: /content/drive/MyDrive/vehicle_detection_final_fixed.h5
#
# ============================================================
#     VEHICLE DETECTION CNN – FINAL CORRECTED RESULTS
# ============================================================
#   Image Size       : 128 x 128
#   Batch Size       : 64
#   Epochs Trained   : 30 / 30
#   Best Val Accuracy: 85.25%
#   Test Accuracy    : 85.00%
#   Test Loss        : 0.4348
#   Train/Val Gap    : 7.75%
# ────────────────────────────────────────────────────────────
#   OVERFITTING FIXES APPLIED:
#   ✅ Batch size        : 32     → 64
#   ✅ Dropout blocks 1&2: 0.25   → 0.20
#   ✅ Dropout head      : 0.50   → 0.40
#   ✅ Learning rate     : 0.0005 → 0.0008
#   ✅ Augmentation      : reduced all ranges
#   ✅ EarlyStopping     : patience 8 → 7
#   ✅ ReduceLROnPlateau : patience 4 → 3
#   ✅ Diagnostic report : added after training
# ============================================================

# %%
# Final evaluation
test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
print(f'Test Accuracy : {test_accuracy * 100:.2f}%')

# Predictions
y_prob = model.predict(test_generator, verbose=0)
y_pred = np.argmax(y_prob, axis=1)
y_true = test_generator.classes
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Test Accuracy : 85.00%
