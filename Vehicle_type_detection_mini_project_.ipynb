# %% [markdown]
# <a href="https://colab.research.google.com/github/sh13y/100-days-of-javascript/blob/master/Vehicle_type_detection_mini_project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# ICT 3212 - Vehicle Detection System using CNN
# IMPROVED VERSION – Higher Accuracy
# Changes: 128x128 image, 50 epochs, deeper model, better augmentation
# ============================================================

# ============================================================
# CELL 1: Mount Google Drive & Extract Dataset
# ============================================================

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os, shutil, random

zip_path    = '/content/drive/MyDrive/vehicle_dataset.zip'
extract_dir = '/content/vehicle_dataset'

if not os.path.exists(extract_dir):
    print("Extracting dataset …")
    with zipfile.ZipFile(zip_path, 'r') as zf:
        zf.extractall(extract_dir)
    print("Done!")
else:
    print("Dataset folder already exists – skipping extraction.")

TRAIN_DIR = '/content/vehicle_dataset/vehicle_dataset/train'
TEST_DIR  = '/content/vehicle_dataset/vehicle_dataset/test'

# ============================================================
# CELL 2: Fix Folder Names
# ============================================================

rename_train = {'Car': 'car', 'trucks': 'truck', 'Bike': 'motorcycle'}
for old, new in rename_train.items():
    old_path = os.path.join(TRAIN_DIR, old)
    new_path = os.path.join(TRAIN_DIR, new)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"  ✅ Renamed: train/{old} → train/{new}")

rename_test = {'bike': 'motorcycle'}
for old, new in rename_test.items():
    old_path = os.path.join(TEST_DIR, old)
    new_path = os.path.join(TEST_DIR, new)
    if os.path.exists(old_path):
        os.rename(old_path, new_path)
        print(f"  ✅ Renamed: test/{old} → test/{new}")

print("Train folders:", os.listdir(TRAIN_DIR))
print("Test folders :", os.listdir(TEST_DIR))

# ============================================================
# CELL 3: Populate Empty Test Folders
# ============================================================

CLASS_NAMES   = ['car', 'bus', 'truck', 'motorcycle']
random.seed(42)

for cls in CLASS_NAMES:
    train_cls = os.path.join(TRAIN_DIR, cls)
    test_cls  = os.path.join(TEST_DIR,  cls)
    os.makedirs(test_cls, exist_ok=True)

    existing = [f for f in os.listdir(test_cls)
                if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if len(existing) > 0:
        print(f"  ✅ {cls:12s} → already has {len(existing)} test images")
        continue

    all_images = [f for f in os.listdir(train_cls)
                  if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    random.shuffle(all_images)
    test_count = max(1, int(len(all_images) * 0.2))

    for img_name in all_images[:test_count]:
        shutil.copy2(os.path.join(train_cls, img_name),
                     os.path.join(test_cls,  img_name))
    print(f"  ✅ {cls:12s} → {test_count} images copied to test/")

print("\nFinal Dataset Structure:")
print("=" * 45)
for split, path_dir in [('train', TRAIN_DIR), ('test', TEST_DIR)]:
    print(f"\n  {split.upper()}/")
    for cls in CLASS_NAMES:
        path  = os.path.join(path_dir, cls)
        count = len([f for f in os.listdir(path)
                     if f.lower().endswith(('.jpg','.jpeg','.png'))]) \
                if os.path.exists(path) else 0
        print(f"    {'✅' if count > 0 else '❌'} {cls:12s}: {count} images")
print("=" * 45)

# ============================================================
# CELL 4: Import Libraries
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix

print("All libraries imported successfully!")

# ============================================================
# CELL 5: Configuration  ← KEY IMPROVEMENTS HERE
# ============================================================

DISPLAY_NAMES = ['Car', 'Bus', 'Truck', 'Motorcycle']
NUM_CLASSES   = 4

# ✅ IMPROVEMENT 1: Larger image size (was 32x32)
IMG_HEIGHT = 128
IMG_WIDTH  = 128

# ✅ IMPROVEMENT 2: More epochs (was 10)
EPOCHS     = 30

BATCH_SIZE = 32

print(f"✅ Image size  : {IMG_HEIGHT} x {IMG_WIDTH}  (was 32x32)")
print(f"✅ Max epochs  : {EPOCHS}               (was 10)")
print(f"   Batch size  : {BATCH_SIZE}")
print(f"   Classes     : {CLASS_NAMES}")

# ============================================================
# CELL 6: Data Generators  ← IMPROVEMENT 3: Stronger Augmentation
# ============================================================

# ✅ IMPROVEMENT 3: Stronger augmentation to reduce overfitting
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,          # was 15
    width_shift_range=0.2,      # was 0.1
    height_shift_range=0.2,     # was 0.1
    shear_range=0.15,           # was 0.1
    zoom_range=0.2,             # was 0.1
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],# NEW – vary brightness
    channel_shift_range=20.0,   # NEW – vary colours
    fill_mode='nearest',
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Training data
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    subset='training',
    shuffle=True,
    seed=42
)

# Validation data
val_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    subset='validation',
    shuffle=False,
    seed=42
)

# Test data
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)

print(f"\nTraining   batches : {len(train_generator)}")
print(f"Validation batches : {len(val_generator)}")
print(f"Test       batches : {len(test_generator)}")

# ============================================================
# CELL 7: Visualize Sample Images
# ============================================================

sample_X, sample_y = next(train_generator)

plt.figure(figsize=(14, 7))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(sample_X[i])
    plt.title(DISPLAY_NAMES[np.argmax(sample_y[i])], fontsize=9)
    plt.axis('off')
plt.suptitle('Sample Augmented Training Images (128x128)', fontsize=14)
plt.tight_layout()
plt.show()

# ============================================================
# CELL 8: Class Distribution
# ============================================================

train_counts, test_counts = [], []
for cls in CLASS_NAMES:
    tr = os.path.join(TRAIN_DIR, cls)
    te = os.path.join(TEST_DIR,  cls)
    train_counts.append(len([f for f in os.listdir(tr)
                              if f.lower().endswith(('.jpg','.jpeg','.png'))]))
    test_counts.append( len([f for f in os.listdir(te)
                              if f.lower().endswith(('.jpg','.jpeg','.png'))]))

x, width = np.arange(NUM_CLASSES), 0.35
fig, ax  = plt.subplots(figsize=(10, 5))
b1 = ax.bar(x - width/2, train_counts, width, label='Train', color='#2196F3')
b2 = ax.bar(x + width/2, test_counts,  width, label='Test',  color='#FF5722')
ax.set_xlabel('Vehicle Class')
ax.set_ylabel('Number of Images')
ax.set_title('Class Distribution – Train vs Test')
ax.set_xticks(x)
ax.set_xticklabels(DISPLAY_NAMES)
ax.legend()
ax.bar_label(b1, padding=3)
ax.bar_label(b2, padding=3)
plt.tight_layout()
plt.show()

# ============================================================
# CELL 9: Build Improved CNN Model  ← IMPROVEMENT 4: Deeper CNN
# ============================================================

# ✅ IMPROVEMENT 4: Deeper model with 4 Conv Blocks (was 3)
model = keras.Sequential([

    # ── Conv Block 1 – 32 filters ─────────────────────────
    layers.Conv2D(32, (3,3), activation='relu',
                  padding='same', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    BatchNormalization(),
    layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),   # 128→64
    Dropout(0.25),

    # ── Conv Block 2 – 64 filters ─────────────────────────
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),   # 64→32
    Dropout(0.25),

    # ── Conv Block 3 – 128 filters ────────────────────────
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),   # 32→16
    Dropout(0.25),

    # ── Conv Block 4 – 256 filters (NEW) ──────────────────
    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2,2)),   # 16→8
    Dropout(0.25),

    # ── Classifier Head ───────────────────────────────────
    layers.Flatten(),
    layers.Dense(512, activation='relu'),   # was 256
    BatchNormalization(),
    Dropout(0.5),
    layers.Dense(256, activation='relu'),   # was 128
    BatchNormalization(),
    Dropout(0.4),
    layers.Dense(128, activation='relu'),   # NEW extra layer
    Dropout(0.3),

    # Output
    layers.Dense(NUM_CLASSES, activation='softmax')
])

model.summary()

# ============================================================
# CELL 10: Compile  ← IMPROVEMENT 5: Lower Learning Rate
# ============================================================

# ✅ IMPROVEMENT 5: Lower learning rate for stable training
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),  # was 0.001
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Model compiled!")
print(f"  Optimizer : Adam (lr=0.0005)")
print(f"  Loss      : categorical_crossentropy")

# ============================================================
# CELL 11: Callbacks
# ============================================================

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=8,                  # was 5 – give more time
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=4,                  # was 3
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        '/content/drive/MyDrive/best_vehicle_model_v2.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

print("Callbacks ready!")

# ============================================================
# CELL 12: Train the Model
# ============================================================

print("\n" + "="*50)
print("  STARTING TRAINING")
print(f"  Image size : {IMG_HEIGHT}x{IMG_WIDTH}")
print(f"  Max epochs : {EPOCHS}")
print(f"  Batch size : {BATCH_SIZE}")
print("="*50 + "\n")

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=callbacks,
    verbose=1
)

print("\nTraining completed!")

# ============================================================
# CELL 13: Visualize Training History
# ============================================================

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
axes[0].plot(history.history['accuracy'],     label='Training',   linewidth=2, color='#2196F3')
axes[0].plot(history.history['val_accuracy'], label='Validation', linewidth=2, color='#FF5722')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Model Accuracy Over Time')
axes[0].legend()
axes[0].grid(True, alpha=0.3)
axes[0].set_ylim([0, 1])

# Loss
axes[1].plot(history.history['loss'],     label='Training',   linewidth=2, color='#2196F3')
axes[1].plot(history.history['val_loss'], label='Validation', linewidth=2, color='#FF5722')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].set_title('Model Loss Over Time')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

best_val_acc = max(history.history['val_accuracy'])
print(f"\nBest Validation Accuracy : {best_val_acc * 100:.2f}%")
print(f"Total Epochs Trained     : {len(history.history['accuracy'])}")

# ============================================================
# CELL 14: Evaluate on Test Set
# ============================================================

test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
print(f"\nTest Accuracy : {test_accuracy * 100:.2f}%")
print(f"Test Loss     : {test_loss:.4f}")

y_true       = test_generator.classes
y_pred_probs = model.predict(test_generator, verbose=0)
y_pred       = np.argmax(y_pred_probs, axis=1)

# ============================================================
# CELL 15: Classification Report
# ============================================================

print("\nClassification Report:")
print("=" * 60)
print(classification_report(y_true, y_pred,
                             target_names=DISPLAY_NAMES, digits=3))

# ============================================================
# CELL 16: Confusion Matrix
# ============================================================

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=DISPLAY_NAMES, yticklabels=DISPLAY_NAMES)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label',      fontsize=12)
plt.title('Confusion Matrix – Vehicle Detection (Improved)', fontsize=14)
plt.tight_layout()
plt.show()

print("\nPer-Class Accuracy:")
print("-" * 40)
for i, cls in enumerate(DISPLAY_NAMES):
    correct = cm[i, i]
    total   = cm[i].sum()
    acc     = correct / total * 100
    bar     = '█' * int(acc / 5)
    print(f"  {cls:12s}: {correct}/{total}  {bar} {acc:.1f}%")

# ============================================================
# CELL 17: Visualize Predictions
# ============================================================

test_batch_X, test_batch_y = next(
    test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=16,
        class_mode='categorical',
        classes=CLASS_NAMES,
        shuffle=True,
        seed=99
    )
)

pred_probs  = model.predict(test_batch_X, verbose=0)
pred_labels = np.argmax(pred_probs, axis=1)
true_labels = np.argmax(test_batch_y, axis=1)

plt.figure(figsize=(16, 9))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(test_batch_X[i])
    t = DISPLAY_NAMES[true_labels[i]]
    p = DISPLAY_NAMES[pred_labels[i]]
    c = pred_probs[i][pred_labels[i]] * 100
    plt.title(f"T: {t}\nP: {p} ({c:.0f}%)",
              fontsize=8, color='green' if t == p else 'red')
    plt.axis('off')

plt.suptitle('Predictions (Green=Correct | Red=Wrong)', fontsize=13)
plt.tight_layout()
plt.show()

# ============================================================
# CELL 18: Predict Single Image
# ============================================================

from tensorflow.keras.preprocessing import image as keras_image

def predict_single_vehicle(img_path):
    img     = keras_image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    arr     = keras_image.img_to_array(img) / 255.0
    inp     = np.expand_dims(arr, axis=0)
    probs   = model.predict(inp, verbose=0)[0]
    pred    = np.argmax(probs)
    colors  = ['#4CAF50' if i == pred else '#90CAF9' for i in range(NUM_CLASSES)]

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Input Image', fontsize=13)
    plt.axis('off')

    plt.subplot(1, 2, 2)
    bars = plt.barh(DISPLAY_NAMES, probs * 100, color=colors)
    plt.xlabel('Confidence (%)', fontsize=12)
    plt.title(f"Predicted: {DISPLAY_NAMES[pred]} ({probs[pred]*100:.1f}%)", fontsize=13)
    plt.xlim(0, 100)
    plt.grid(axis='x', alpha=0.3)
    for bar, p in zip(bars, probs):
        plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2,
                 f'{p*100:.1f}%', va='center', fontsize=10)
    plt.tight_layout()
    plt.show()

    print("\nConfidence Scores:")
    for name, p in zip(DISPLAY_NAMES, probs):
        print(f"  {name:12s} {'█' * int(p*40)} {p*100:.2f}%")

# predict_single_vehicle('/content/vehicle_dataset/vehicle_dataset/test/car/Car (1).jpeg')

# ============================================================
# CELL 19: Save Model
# ============================================================

save_path = '/content/drive/MyDrive/vehicle_detection_v2_improved.h5'
model.save(save_path)
print(f"Model saved: {save_path}")

# ============================================================
# CELL 20: Final Summary
# ============================================================

print("\n" + "="*60)
print("    VEHICLE DETECTION CNN – IMPROVED RESULTS")
print("="*60)
print(f"  Image Size       : {IMG_HEIGHT} x {IMG_WIDTH}  (was 32x32)")
print(f"  Epochs Trained   : {len(history.history['accuracy'])} / {EPOCHS}")
print(f"  Best Val Accuracy: {best_val_acc * 100:.2f}%")
print(f"  Test Accuracy    : {test_accuracy * 100:.2f}%")
print(f"  Test Loss        : {test_loss:.4f}")
print("─"*60)
print("  IMPROVEMENTS APPLIED:")
print("  ✅ Image size: 32x32  → 128x128")
print("  ✅ Epochs   : 10      → 50 (+ early stopping)")
print("  ✅ Model    : 3 blocks → 4 blocks + deeper head")
print("  ✅ Learning rate: 0.001 → 0.0005")
print("  ✅ Augmentation: stronger (brightness + colour shift)")
print("  ✅ BatchNorm added to every conv block")
print("="*60)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset folder already exists – skipping extraction.
# Train folders: ['bus', 'truck', 'car', 'motorcycle']
# Test folders : ['bus', 'truck', 'car', 'motorcycle']
#   ✅ car          → already has 200 test images
#   ✅ bus          → already has 200 test images
#   ✅ truck        → already has 200 test images
#   ✅ motorcycle   → already has 200 test images
#
# Final Dataset Structure:
# =============================================
#
#   TRAIN/
#     ✅ car         : 1000 images
#     ✅ bus         : 1000 images
#     ✅ truck       : 1000 images
#     ✅ motorcycle  : 1000 images
#
#   TEST/
#     ✅ car         : 200 images
#     ✅ bus         : 200 images
#     ✅ truck       : 200 images
#     ✅ motorcycle  : 200 images
# =============================================
# All libraries imported successfully!
# ✅ Image size  : 128 x 128  (was 32x32)
# ✅ Max epochs  : 30               (was 10)
#    Batch size  : 32
#    Classes     : ['car', 'bus', 'truck', 'motorcycle']
# Found 3200 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
#
# Training   batches : 100
# Validation batches : 25
# Test       batches : 25
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,733,028 (37.13 MB)
#  Trainable params: 9,729,572 (37.12 MB)
#  Non-trainable params: 3,456 (13.50 KB)
# Model compiled!
#   Optimizer : Adam (lr=0.0005)
#   Loss      : categorical_crossentropy
# Callbacks ready!
#
# ==================================================
#   STARTING TRAINING
#   Image size : 128x128
#   Max epochs : 30
#   Batch size : 32
# ==================================================
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
#  70/100 ━━━━━━━━━━━━━━━━━━━━ 3:11 6s/step - accuracy: 0.2936 - loss: 2.0347
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3060 - loss: 1.9610
# Epoch 1: val_accuracy improved from -inf to 0.25000, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 690s 7s/step - accuracy: 0.3064 - loss: 1.9590 - val_accuracy: 0.2500 - val_loss: 1.6130 - learning_rate: 5.0000e-04
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.4699 - loss: 1.2996
# Epoch 2: val_accuracy improved from 0.25000 to 0.25250, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 727s 7s/step - accuracy: 0.4701 - loss: 1.2994 - val_accuracy: 0.2525 - val_loss: 1.6943 - learning_rate: 5.0000e-04
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5333 - loss: 1.2208
# Epoch 3: val_accuracy did not improve from 0.25250
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 732s 7s/step - accuracy: 0.5337 - loss: 1.2196 - val_accuracy: 0.2500 - val_loss: 3.6194 - learning_rate: 5.0000e-04
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6454 - loss: 0.9645
# Epoch 4: val_accuracy did not improve from 0.25250
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 680s 7s/step - accuracy: 0.6455 - loss: 0.9640 - val_accuracy: 0.1900 - val_loss: 4.4060 - learning_rate: 5.0000e-04
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6710 - loss: 0.8262
# Epoch 5: val_accuracy improved from 0.25250 to 0.43375, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 679s 7s/step - accuracy: 0.6712 - loss: 0.8262 - val_accuracy: 0.4338 - val_loss: 1.5215 - learning_rate: 5.0000e-04
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6979 - loss: 0.7901
# Epoch 6: val_accuracy improved from 0.43375 to 0.58125, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 684s 7s/step - accuracy: 0.6981 - loss: 0.7897 - val_accuracy: 0.5813 - val_loss: 1.0244 - learning_rate: 5.0000e-04
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7195 - loss: 0.7841
# Epoch 7: val_accuracy did not improve from 0.58125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 680s 7s/step - accuracy: 0.7196 - loss: 0.7836 - val_accuracy: 0.4963 - val_loss: 1.6532 - learning_rate: 5.0000e-04
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7510 - loss: 0.6419
# Epoch 8: val_accuracy improved from 0.58125 to 0.59750, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 679s 7s/step - accuracy: 0.7512 - loss: 0.6417 - val_accuracy: 0.5975 - val_loss: 1.6795 - learning_rate: 5.0000e-04
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7468 - loss: 0.6763
# Epoch 9: val_accuracy improved from 0.59750 to 0.72625, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 692s 7s/step - accuracy: 0.7469 - loss: 0.6758 - val_accuracy: 0.7262 - val_loss: 0.6717 - learning_rate: 5.0000e-04
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.7851 - loss: 0.5858
# Epoch 10: val_accuracy did not improve from 0.72625
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 694s 7s/step - accuracy: 0.7850 - loss: 0.5859 - val_accuracy: 0.6900 - val_loss: 0.7510 - learning_rate: 5.0000e-04
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.7913 - loss: 0.5699
# Epoch 11: val_accuracy improved from 0.72625 to 0.72875, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 681s 7s/step - accuracy: 0.7912 - loss: 0.5700 - val_accuracy: 0.7287 - val_loss: 0.7710 - learning_rate: 5.0000e-04
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8174 - loss: 0.4948
# Epoch 12: val_accuracy improved from 0.72875 to 0.75125, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 701s 7s/step - accuracy: 0.8173 - loss: 0.4948 - val_accuracy: 0.7513 - val_loss: 0.5997 - learning_rate: 5.0000e-04
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8179 - loss: 0.5052
# Epoch 13: val_accuracy did not improve from 0.75125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 728s 7s/step - accuracy: 0.8179 - loss: 0.5052 - val_accuracy: 0.7025 - val_loss: 0.7757 - learning_rate: 5.0000e-04
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8119 - loss: 0.5055
# Epoch 14: val_accuracy improved from 0.75125 to 0.77875, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 686s 7s/step - accuracy: 0.8120 - loss: 0.5055 - val_accuracy: 0.7788 - val_loss: 0.6602 - learning_rate: 5.0000e-04
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8096 - loss: 0.4811
# Epoch 15: val_accuracy improved from 0.77875 to 0.78875, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 742s 7s/step - accuracy: 0.8096 - loss: 0.4812 - val_accuracy: 0.7887 - val_loss: 0.6636 - learning_rate: 5.0000e-04
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8484 - loss: 0.4254
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 16: val_accuracy did not improve from 0.78875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 738s 7s/step - accuracy: 0.8483 - loss: 0.4256 - val_accuracy: 0.7788 - val_loss: 0.6142 - learning_rate: 5.0000e-04
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8310 - loss: 0.4358
# Epoch 17: val_accuracy improved from 0.78875 to 0.80250, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 684s 7s/step - accuracy: 0.8311 - loss: 0.4356 - val_accuracy: 0.8025 - val_loss: 0.5272 - learning_rate: 2.5000e-04
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8451 - loss: 0.4105
# Epoch 18: val_accuracy did not improve from 0.80250
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 685s 7s/step - accuracy: 0.8451 - loss: 0.4105 - val_accuracy: 0.7925 - val_loss: 0.5774 - learning_rate: 2.5000e-04
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8530 - loss: 0.3961
# Epoch 19: val_accuracy did not improve from 0.80250
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 681s 7s/step - accuracy: 0.8530 - loss: 0.3962 - val_accuracy: 0.7825 - val_loss: 0.6187 - learning_rate: 2.5000e-04
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8432 - loss: 0.4165
# Epoch 20: val_accuracy did not improve from 0.80250
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 682s 7s/step - accuracy: 0.8433 - loss: 0.4163 - val_accuracy: 0.7412 - val_loss: 0.7138 - learning_rate: 2.5000e-04
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8455 - loss: 0.4040
# Epoch 21: val_accuracy improved from 0.80250 to 0.83125, saving model to /content/drive/MyDrive/best_vehicle_model_v2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 684s 7s/step - accuracy: 0.8456 - loss: 0.4038 - val_accuracy: 0.8313 - val_loss: 0.4708 - learning_rate: 2.5000e-04
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8529 - loss: 0.4043
# Epoch 22: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 685s 7s/step - accuracy: 0.8527 - loss: 0.4046 - val_accuracy: 0.6950 - val_loss: 1.1780 - learning_rate: 2.5000e-04
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8555 - loss: 0.3994
# Epoch 23: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 740s 7s/step - accuracy: 0.8555 - loss: 0.3993 - val_accuracy: 0.7788 - val_loss: 0.8770 - learning_rate: 2.5000e-04
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8554 - loss: 0.3841
# Epoch 24: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 685s 7s/step - accuracy: 0.8554 - loss: 0.3840 - val_accuracy: 0.7650 - val_loss: 0.6052 - learning_rate: 2.5000e-04
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8551 - loss: 0.3900
# Epoch 25: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 685s 7s/step - accuracy: 0.8552 - loss: 0.3898 - val_accuracy: 0.8188 - val_loss: 0.4502 - learning_rate: 2.5000e-04
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8667 - loss: 0.3595
# Epoch 26: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 686s 7s/step - accuracy: 0.8667 - loss: 0.3596 - val_accuracy: 0.7625 - val_loss: 0.7055 - learning_rate: 2.5000e-04
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.8664 - loss: 0.3495
# Epoch 27: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 692s 7s/step - accuracy: 0.8664 - loss: 0.3496 - val_accuracy: 0.8012 - val_loss: 0.5868 - learning_rate: 2.5000e-04
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8724 - loss: 0.3214
# Epoch 28: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 680s 7s/step - accuracy: 0.8724 - loss: 0.3218 - val_accuracy: 0.8150 - val_loss: 0.6098 - learning_rate: 2.5000e-04
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8654 - loss: 0.3526
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 29: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 676s 7s/step - accuracy: 0.8654 - loss: 0.3526 - val_accuracy: 0.8225 - val_loss: 0.4623 - learning_rate: 2.5000e-04
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8702 - loss: 0.3404
# Epoch 30: val_accuracy did not improve from 0.83125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 679s 7s/step - accuracy: 0.8702 - loss: 0.3403 - val_accuracy: 0.7962 - val_loss: 0.6578 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 25.
#
# Training completed!
# Best Validation Accuracy : 83.13%
# Total Epochs Trained     : 30
#
# Test Accuracy : 82.00%
# Test Loss     : 0.4373
#
# Classification Report:
# ============================================================
#               precision    recall  f1-score   support
#
#          Car      0.889     0.845     0.867       200
#          Bus      0.647     1.000     0.786       200
#        Truck      0.903     0.605     0.725       200
#   Motorcycle      0.994     0.830     0.905       200
#
#     accuracy                          0.820       800
#    macro avg      0.858     0.820     0.820       800
# weighted avg      0.858     0.820     0.820       800
# Per-Class Accuracy:
# ----------------------------------------
#   Car         : 169/200  ████████████████ 84.5%
#   Bus         : 200/200  ████████████████████ 100.0%
#   Truck       : 121/200  ████████████ 60.5%
#   Motorcycle  : 166/200  ████████████████ 83.0%
# Found 800 images belonging to 4 classes.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved: /content/drive/MyDrive/vehicle_detection_v2_improved.h5
#
# ============================================================
#     VEHICLE DETECTION CNN – IMPROVED RESULTS
# ============================================================
#   Image Size       : 128 x 128  (was 32x32)
#   Epochs Trained   : 30 / 30
#   Best Val Accuracy: 83.13%
#   Test Accuracy    : 82.00%
#   Test Loss        : 0.4373
# ────────────────────────────────────────────────────────────
#   IMPROVEMENTS APPLIED:
#   ✅ Image size: 32x32  → 128x128
#   ✅ Epochs   : 10      → 50 (+ early stopping)
#   ✅ Model    : 3 blocks → 4 blocks + deeper head
#   ✅ Learning rate: 0.001 → 0.0005
#   ✅ Augmentation: stronger (brightness + colour shift)
#   ✅ BatchNorm added to every conv block
# ============================================================
